# %% [markdown]
# <a href="https://colab.research.google.com/github/evan-br/hello-world/blob/master/Salarios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.tree import DecisionTreeClassifier, plot_tree

# %%
df = pd.read_csv("rg_salario.csv")

# %%
df.head()
# Out:
#    anos_experiencia  salario
# 0               1.1  39343.0
# 1               1.3  46205.0
# 2               1.5  37731.0
# 3               2.0  43525.0
# 4               2.2  39891.0

# %%
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
y
# Out:
# 0      39343.0
# 1      46205.0
# 2      37731.0
# 3      43525.0
# 4      39891.0
# 5      56642.0
# 6      60150.0
# 7      54445.0
# 8      64445.0
# 9      57189.0
# 10     63218.0
# 11     55794.0
# 12     56957.0
# 13     57081.0
# 14     61111.0
# 15     67938.0
# 16     66029.0
# 17     83088.0
# 18     81363.0
# 19     93940.0
# 20     91738.0
# 21     98273.0
# 22    101302.0
# 23    113812.0
# 24    109431.0
# 25    105582.0
# 26    116969.0
# 27    112635.0
# 28    122391.0
# 29    121872.0
# Name: salario, dtype: float64

# %%
arvore = DecisionTreeRegressor()


arvore.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')

# %%
plt.figure(figsize=(25, 10))
a1 = plot_tree(arvore,
               feature_names=['anos_experiencia'],
               filled=True,
               rounded=True,
               fontsize=14)

# %%
arvore.feature_importances_
# Out:
# array([1.])

# %%
arvore.predict(X_test.iloc[[0], :])
# Out:
# array([54445.])

# %%
y_pred = arvore.predict(X_test)
y_pred
# Out:
# array([54445., 93940., 63218., 46205., 63218., 39891.])

# %%
r2_score(y_test, y_pred)
# Out:
# 0.6361694527316848

# %%
rf = RandomForestRegressor(100)
rf.fit(X_train, y_train)
y_pred_rf = rf.predict(X_test)
y_pred_rf

r2_score(y_test, y_pred_rf)
# Out:
# 0.8164199105037577

# %%
X_test.iloc[[0], :]
# Out:
#    anos_experiencia
# 8               3.2
